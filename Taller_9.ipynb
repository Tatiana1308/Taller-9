# %% [markdown]
# # Estatura de estudiantes

# %%
import numpy as np
import matplotlib.pyplot as plt

datos = np.array ([[1.88,1.60,1.60,1.60,1.60,1.60,1.65,1.59,1.75,1.59,1.72,1.74,1.80,1.85,1.70,1.50,1.54,1.60]])

media= np.mean(datos)
media
# Out:
# 1.6616666666666666

# %%
mediana= np.median(datos)
mediana
# Out:
# 1.6

# %%
desviacion= np.std(datos)
desviacion
# Out:
# 0.10414999866645326

# %%
elevacion=np.random.randint(0,200, size=(100,100))
elevacion
plt.imshow (elevacion, cmap ="terrain")
plt.colorbar(label="Altura(cm)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
